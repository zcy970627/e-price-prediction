# %% [markdown]
# https://towardsdatascience.com/obtain-historical-weather-forecast-data-in-csv-format-using-python-5a6c090fc828

# %% [markdown]
# https://github.com/ekapope/WorldWeatherOnline

# %% [markdown]
# <details>
# <summary>
# <a class="btnfire small stroke"><em class="fas fa-chevron-circle-down"></em>&nbsp;&nbsp;Output column names:</a>
# </summary>
#
#
# * `date_time`
#
# * `maxtempC`
#
# * `mintempC`
#
# * `totalSnow_cm`
#
# * `sunHour`
#
# * `uvIndex`
#
# * `uvIndex`
#
# * `moon_illumination`
#
# * `moonrise`
#
# * `moonset`
#
# * `sunrise`
#
# * `sunset`
#
# * `DewPointC`
#
# * `FeelsLikeC`
#
# * `HeatIndexC`
#
# * `WindChillC`
#
# * `WindGustKmph`
#
# * `cloudcover`
#
# * `humidity`
#
# * `precipMM`
#
# * `pressure`
#
# * `tempC`
#
# * `visibility`
#
# * `winddirDegree`
#
# * `windspeedKmph`
# </details>
# <br\><br\>

# %%
# import package
from wwo_hist import retrieve_hist_data
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fadc66483e33> in <module>
#       1 # import package
# ----> 2 from wwo_hist import retrieve_hist_data
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'wwo_hist'

# %%
# set working directory to store output csv file(s)
import os
os.chdir("/Users/chennan/Downloads") #
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8202ad96e7eb> in <module>
#       1 # set working directory to store output csv file(s)
#       2 import os
# ----> 3 os.chdir("/Users/chennan/Downloads") #
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/Users/chennan/Downloads'

# %%
frequency = 1
start_date = '11-MAY-2016'
end_date = '20-JUN-2021'
api_key = 'c14f9bc7dd554bfcb43135007212006' # YOUR API KEY
location_list = ['munich','leipzig']
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0b2ffd6d0121> in <module>
#       4 api_key = 'c14f9bc7dd554bfcb43135007212006' # YOUR API KEY
#       5 location_list = ['munich','leipzig']
# ----> 6 hist_weather_data = retrieve_hist_data(api_key,
#       7                                 location_list,
#       8                                 start_date,
#
# NameError: name 'retrieve_hist_data' is not defined

# %%
data1 = pd.read_csv('munich.csv')
data1
# Out:
#                  date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0      2016-05-11 00:00:00        21         8           0.0     13.5
# 1      2016-05-11 01:00:00        21         8           0.0     13.5
# 2      2016-05-11 02:00:00        21         8           0.0     13.5
# 3      2016-05-11 03:00:00        21         8           0.0     13.5
# 4      2016-05-11 04:00:00        21         8           0.0     13.5
# ...                    ...       ...       ...           ...      ...
# 44803  2021-06-20 19:00:00        30        17           0.0     15.6
# 44804  2021-06-20 20:00:00        30        17           0.0     15.6
# 44805  2021-06-20 21:00:00        30        17           0.0     15.6
# 44806  2021-06-20 22:00:00        30        17           0.0     15.6
# 44807  2021-06-20 23:00:00        30        17           0.0     15.6
#
#        uvIndex  moon_illumination  moonrise   moonset   sunrise  ...  \
# ...

# %%
data2 = pd.read_csv('leipzig.csv')
data2
# Out:
#                 date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0     2020-05-11 00:00:00         5         2           0.0      9.5        1
# 1     2020-05-11 03:00:00         5         2           0.0      9.5        1
# 2     2020-05-11 06:00:00         5         2           0.0      9.5        1
# 3     2020-05-11 09:00:00         5         2           0.0      9.5        1
# 4     2020-05-11 12:00:00         5         2           0.0      9.5        1
# ...                   ...       ...       ...           ...      ...      ...
# 3243  2021-06-20 09:00:00        31        19           0.0     15.8        6
# 3244  2021-06-20 12:00:00        31        19           0.0     15.8        6
# 3245  2021-06-20 15:00:00        31        19           0.0     15.8        6
# 3246  2021-06-20 18:00:00        31        19           0.0     15.8        6
# 3247  2021-06-20 21:00:00        31        19           0.0     15.8        6
#
# ...
